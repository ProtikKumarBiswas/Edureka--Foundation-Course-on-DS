# %% [markdown]
# ### About Dataset
#
# #### Context
# This is the dataset is a modified version of the California Housing Data used in the paper Pace, R. Kelley, and Ronald Barry. "Sparse spatial autoregressions." Statistics & Probability Letters 33.3 (1997): 291-297.. It serves as an excellent introduction to implementing machine learning algorithms because it requires rudimentary data cleaning, has an easily understandable list of variables and sits at an optimal size between being too toyish and too cumbersome.
#
# The data contains information from the 1990 California census. So although it may not help you with predicting current housing prices like the Zillow Zestimate dataset, it does provide an accessible introductory dataset for teaching people about the basics of machine learning.

# %% [markdown]
# #### Content
# The data pertains to the houses found in a given California district and some summary stats about them based on the 1990 census data. The columns are as follows, their names are pretty self-explanatory:
#
#     1) Median House Value: Median house value for households within a block (measured in US Dollars)
#     2) Median Income: Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#     3) Median Age: Median age of a house within a block; a lower number is a newer building [years]
#     4) Total Rooms: Total number of rooms within a block
#     5) Total Bedrooms: Total number of bedrooms within a block
#     6) Population: Total number of people residing within a block
#     7) Households: Total number of households, a group of people residing within a home unit, for a block
#     8) Latitude: A measure of how far north a house is; a higher value is farther north [°]
#     9) Longitude: A measure of how far west a house is; a higher value is farther west [°]
#     10) Distance to coast: Distance to the nearest coast point [m]
#     11) Distance to Los Angeles: Distance to the centre of Los Angeles [m]
#     12) Distance to San Diego: Distance to the centre of San Diego [m]
#     13) Distance to San Jose: Distance to the centre of San Jose [m]
#     14) Distance to San Francisco: Distance to the centre of San Francisco [m]

# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd #Provides Data structure for DS tasks
import matplotlib.pyplot as plt #graphs plot
import seaborn as sns #more interactive graphs

# %% [markdown]
# #### Importing Dataset

# %%
df = pd.read_csv("California_Houses.csv")

# %%
df
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
df.shape
# Out:
# (20640, 14)

# %% [markdown]
# ##### Observation:
# - There are 20640 points in the dataset. Each point is the statistics of the houses on different blocks.
# - There are 14 columns on the dataset which is 5 more than the original California House Dataset.

# %%
df.describe()
# Out:
#        Median_House_Value  Median_Income    Median_Age     Tot_Rooms  \
# count        20640.000000   20640.000000  20640.000000  20640.000000
# mean        206855.816909       3.870671     28.639486   2635.763081
# std         115395.615874       1.899822     12.585558   2181.615252
# min          14999.000000       0.499900      1.000000      2.000000
# 25%         119600.000000       2.563400     18.000000   1447.750000
# 50%         179700.000000       3.534800     29.000000   2127.000000
# 75%         264725.000000       4.743250     37.000000   3148.000000
# max         500001.000000      15.000100     52.000000  39320.000000
#
#        Tot_Bedrooms    Population    Households      Latitude     Longitude  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean     537.898014   1425.476744    499.539680     35.631861   -119.569704
# std      421.247906   1132.462122    382.329753      2.135952      2.003532
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
# ...

# %% [markdown]
# ##### Observation:
# - There are no null values on the dataset or outliers as this dataset is already came almost preprocessed from Kaggle.
# - It can be observed that Median_House_Value does not have floating value but has float data type.

# %%
if df.Median_House_Value.apply(lambda x: bool(x%1)).sum():
    print("There is floating value in the 'Median_House_Value'")
else:
    print("'Median_House_Value' can be converted to 'int'")
# Out:
# 'Median_House_Value' can be converted to 'int'

# %%
#Converting the Median_House_Value to int.
df.Median_House_Value = df.Median_House_Value.astype("int")

# %% [markdown]
# #### Spliting the data to Independent Variable (X) and Dependent Variable (Y)

# %%
X = df.drop("Median_House_Value", axis=1)

# %%
y = df["Median_House_Value"]

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Graphical

# %%
i = 1
plt.figure(figsize=(20, 20))
for col in X.columns:
    plt.subplot(5, 3, i)
    sns.kdeplot(data=df, x=col) 
    i+=1
plt.show()

# %% [markdown]
# ##### Observation:
# - All the distance bases features like 'Longitude', 'Latitude', 'Distance_to_Sanjose', etc seem to have double peaks.
# - 'population', 'Median_Income', 'Tot_room' etc are right skewed(have a longer tail on the right).
# - Distribution 'Median_Age' does not seeem to follow any commonly known distribution.

# %%
sns.scatterplot(df.Longitude, df.Latitude)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
import plotly.express as px

# %%
fig = px.scatter(df, x='Longitude', y='Latitude', color="Median_House_Value", width=1000, height=700) 
fig.show()
# Out:
# <div>                            <div id="06f1e234-e1be-49de-9985-d5db31f8f7de" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06f1e234-e1be-49de-9985-d5db31f8f7de")) {                    Plotly.newPlot(                        "06f1e234-e1be-49de-9985-d5db31f8f7de",                        [{"hovertemplate":"Longitude=%{x}<br>Latitude=%{y}<br>Median_House_Value=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[452600,358500,352100,341300,342200,269700,299200,241400,226700,261100,281500,241800,213500,191300,159200,140000,152500,155500,158700,162900,147500,159800,113900,99700,132600,107500,93800,105500,108900,132000,122300,115200,110400,104900,109700,97200,104500,103900,191400,176000,155400,150000,118800,188800,184400,182300,142500
# ...
